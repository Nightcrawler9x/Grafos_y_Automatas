# %% [markdown]
# ###Simulación duelo de karate

# %% [markdown]
# **Oscar Miguel Ortega Lozano**

# %%
pip install automata-lib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 kB 3.1 MB/s eta 0:00:00
# ...

# %%
from automata.tm.mntm import MNTM

turing1 = MNTM(
   states={"q0", "qSR", "qSA", "qFR", "qFA", "qA8", "qR8",
            "qR1", "qR2", "qR3", "qR4", "qR5", "qR6", "qR7",
            "qA1",  "qA2",  "qA3", "qA4",  "qA5",  "qA6",  "qA7", "qFR0", "qFA0",
            "qFR_1_1", "qFR_1_2", "qFR_1_3", "qFR_1_4", "qFR_1_5", "qFR_1_6", "qFR_1_7",
            "qFA_1_1", "qFA_1_2", "qFA_1_3", "qFA_1_4", "qFA_1_5", "qFA_1_6", "qFA_1_7",
            "qFR_2_1", "qFR_2_2", "qFR_2_3", "qFR_2_4", "qFR_2_5", "qFR_2_6", "qFR_2_7",
            "qFA_2_1", "qFA_2_2", "qFA_2_3", "qFA_2_4", "qFA_2_5", "qFA_2_6", "qFA_2_7",
           },
    input_symbols={"1", "2", "3", "Y", "W", "I", "A", "R", "T", "a", "r"},
    tape_symbols={"1", "2", "3", "Y", "W", "I", "A", "R", "T", "a","r","B","4","5"},
    n_tapes=5,
    transitions={
        'q0': {("a", "B", "B","B", "B"): [("qSA", (("a", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
               ("r", "B", "B","B", "B") : [("qSR", (("r", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
               ("Y", "B", "B","B", "B") : [("qR1", (("Y", "R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
               ("W", "B", "B","B", "B") : [("qR2", (("W", "R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
               ("I", "B", "B","B", "B") : [("qR3", (("I", "R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
               ("1", "B", "B","B", "B") : [("qA1", (("1", "R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
               ("2", "B", "B","B", "B") : [("qA2", (("2", "R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
               ("3", "B", "B","B", "B") : [("qA3", (("3", "R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
               ("A", "B", "B","B", "B") : [("qFA0", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
               ("R", "B", "B","B", "B") : [("qFR0", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
               ("T","B","B","B", "B") : [("q0", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
        },


        "qA1": {("1", "B", "B","B", "B") : [("qA2", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA3", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA4", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("q0", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR1", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR2", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_1", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_1", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA2": {("1", "B", "B","B", "B") : [("qA3", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA4", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA5", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA1", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("q0", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR1", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_2", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_2", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA3": {("1", "B", "B","B", "B") : [("qA4", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA5", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA6", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA2", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qA1", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("q0", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_3", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_3", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA4": {("1", "B", "B","B", "B") : [("qA5", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA6", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA7", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA3", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR2", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR1", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_4", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_4", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA5": {("1", "B", "B","B", "B") : [("qA6", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA7", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA8", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA4", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qA3", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qA2", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_5", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_5", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA6": {("1", "B", "B","B", "B") : [("qA7", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA8", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA8", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA5", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qA4", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qA3", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_6", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_6", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },
        "qA7": {("1", "B", "B","B", "B") : [("qA8", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA8", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA8", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("Y", "B", "B","B", "B") : [("qA6", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qA5", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qA4", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qA8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_2_7", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_2_7", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

        "qR1": {("Y", "B", "B","B", "B") : [("qR2", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR3", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR4", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("q0", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qA1", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA2", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_1", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_1", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

        "qR2": {("Y", "B", "B","B", "B") : [("qR3", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR4", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR5", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("qR1", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("q0", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qA1", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_2", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_2", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

        "qR3": {("Y", "B", "B","B", "B") : [("qR4", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR5", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR6", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("qR2", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qR1", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("q0", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_3", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_3", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

        "qR4": {("Y", "B", "B","B", "B") : [("qR5", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "R"), ("B", "R")))],
                ("W", "B", "B","B", "B") : [("qR6", (("W","R"), ("B", "N"), ("2", "R"), ("B", "R"), ("B", "R")))],
                ("I", "B", "B","B", "B") : [("qR7", (("I","R"), ("B", "N"), ("3", "R"), ("B", "R"), ("B", "R")))],
                ("1", "B", "B","B", "B") : [("qR3", (("1","R"), ("1", "R"), ("B", "N"), ("B", "R"), ("B", "R")))],
                ("2", "B", "B","B", "B") : [("qR2", (("2","R"), ("2", "R"), ("B", "N"), ("B", "R"), ("B", "R")))],
                ("3", "B", "B","B", "B") : [("qR1", (("3","R"), ("3", "R"), ("B", "N"), ("B", "R"), ("B", "R")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "R")))],
                ("A", "B", "B","B", "B") : [("qFA_1_4", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_4", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

      "qR5": {("Y", "B", "B","B", "B") : [("qR6", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR7", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR8", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("qR4", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qR3", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qR2", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_5", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_5", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],

        },

        "qR6": {("Y", "B", "B","B", "B") : [("qR7", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR8", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR8", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("qR5", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qR4", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qR3", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_6", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_6", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],

        },

        "qR7": {("Y", "B", "B","B", "B") : [("qR8", (("Y","R"), ("B", "N"), ("1", "R"), ("B", "N"), ("B", "N")))],
                ("W", "B", "B","B", "B") : [("qR8", (("W","R"), ("B", "N"), ("2", "R"), ("B", "N"), ("B", "N")))],
                ("I", "B", "B","B", "B") : [("qR8", (("I","R"), ("B", "N"), ("3", "R"), ("B", "N"), ("B", "N")))],
                ("1", "B", "B","B", "B") : [("qR6", (("1","R"), ("1", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("2", "B", "B","B", "B") : [("qR5", (("2","R"), ("2", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("3", "B", "B","B", "B") : [("qR4", (("3","R"), ("3", "R"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("T", "B", "B","B", "B") : [("qR8", (("T","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "N")))],
                ("A", "B", "B","B", "B") : [("qFA_1_7", (("A", "N"), ("B", "N"), ("B", "N"), ("B", "R"), ("B", "N")))],
                ("R", "B", "B","B", "B") : [("qFR_1_7", (("R", "N"), ("B", "N"), ("B", "N"), ("B", "N"), ("B", "R")))],
        },

        "qFR_1_1": {("R", "B", "B","B", "B") : [("qR1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_1": {("A", "B", "B","B", "B") : [("qR1", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR1", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR1", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR1", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_1_2": {("R", "B", "B","B", "B") : [("qR2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_2": {("A", "B", "B","B", "B") : [("qR2", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR2", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR2", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR2", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_1_3": {("R", "B", "B","B", "B") : [("qR3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_3": {("A", "B", "B","B", "B") : [("qR3", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR3", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR3", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR3", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

       "qFR_1_4": {("R", "B", "B","B", "B") : [("qR4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_4": {("A", "B", "B","B", "B") : [("qR4", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR4", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR4", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR4", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_1_5": {("R", "B", "B","B", "B") : [("qR5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_5": {("A", "B", "B","B", "B") : [("qR5", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR5", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR5", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR5", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_1_6": {("R", "B", "B","B", "B") : [("qR6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_6": {("A", "B", "B","B", "B") : [("qR6", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR6", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR6", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR6", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_1_7": {("R", "B", "B","B", "B") : [("qR7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qR7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qR7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qR7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_1_7": {("A", "B", "B","B", "B") : [("qR7", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qR7", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qR7", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qR7", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_1": {("R", "B", "B","B", "B") : [("qA1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA1", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_1": {("A", "B", "B","B", "B") : [("qA1", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA1", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA1", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA1", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },


        "qFR_2_2": {("R", "B", "B","B", "B") : [("qA2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA2", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA_2_2": {("A", "B", "B","B", "B") : [("qA2", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA2", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA2", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA2", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_3": {("R", "B", "B","B", "B") : [("qA3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA3", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_3": {("A", "B", "B","B", "B") : [("qA3", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA3", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA3", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA3", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_4": {("R", "B", "B","B", "B") : [("qA4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA4", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_4": {("A", "B", "B","B", "B") : [("qA4", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA4", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA4", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA4", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_5": {("R", "B", "B","B", "B") : [("qA5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA5", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_5": {("A", "B", "B","B", "B") : [("qA5", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA5", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA5", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA5", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_6": {("R", "B", "B","B", "B") : [("qA6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("qA6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("qA6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("qA6", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_6": {("A", "B", "B","B", "B") : [("qA6", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA6", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA6", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA6", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },

        "qFR_2_7": {("R", "B", "B","B", "B") : [("qA7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","1", "B") : [("qA7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","2", "B") : [("qA7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","3", "B") : [("qA7", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","4", "B") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },
        "qFA_2_7": {("A", "B", "B","B", "B") : [("qA7", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("qA7", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("qA7", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("qA7", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },
        "qFR0": {("R", "B", "B","B", "B") : [("q0", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("1", "L")))],
                ("R", "B", "B","B", "1") : [("q0", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("2", "L")))],
                ("R", "B", "B","B", "2") : [("q0", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("3", "L")))],
                ("R", "B", "B","B", "3") : [("q0", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("4", "L")))],
                ("R", "B", "B","B", "4") : [("qFA", (("R","R"), ("B", "N"), ("B", "N"), ("B", "N"), ("5", "N")))],
        },

        "qFA0": {("A", "B", "B","B", "B") : [("q0", (("A","R"), ("B", "N"), ("B", "N"), ("1", "L"), ("B", "N")))],
                ("A", "B", "B","1", "B") : [("q0", (("A","R"), ("B", "N"), ("B", "N"), ("2", "L"), ("B", "N")))],
                ("A", "B", "B","2", "B") : [("q0", (("A","R"), ("B", "N"), ("B", "N"), ("3", "L"), ("B", "N")))],
                ("A", "B", "B","3", "B") : [("q0", (("A","R"), ("B", "N"), ("B", "N"), ("4", "L"), ("B", "N")))],
                ("A", "B", "B","4", "B") : [("qFR", (("A","R"), ("B", "N"), ("B", "N"), ("5", "N"), ("B", "N")))],
        },
    },
    initial_state='q0',
    blank_symbol='B',
    final_states={"qSR", "qSA", "qFR", "qFA", "qA8", "qR8"}
)

def Combatir(cadenaJuego):

        print("Cadena de combate:", cadenaJuego)
        print("")

        Tape1 = turing1.read_input(cadenaJuego).pop().tapes[0].tape
        for i in range(len(Tape1)):
                play = Tape1[i]
                match play:
                        case "T":
                                print("Tiempo!")
                        case "1":
                                print("Yame! Ao: yuko! (Azul marcó 1 punto)")
                        case "2":
                                print("Yame! Ao: wazari! (Azul marcó 2 puntos)")
                        case "3":
                                print("Yame! Ao: ippon! (Azul marcó 3 puntos)")
                        case "Y":
                                print("Yame! Aka: yuko! (Rojo marcó 1 punto)")
                        case "W":
                                print("Yame! Aka: wazari! (Rojo marcó 2 puntos)")
                        case "I":
                                print("Yame! Aka: ippon! (Rojo marcó 3 puntos)")
                        case "A":
                                print("Yame! Ao: chui! (Azul cometió falta)")
                        case "R":
                                print("Yame! Aka: chui! (Rojo cometió falta)")
                        case "a":
                                print("Ao senshu! (Azul marcó el primer punto)")
                        case "r":
                                print("Aka senshu! (Rojo marcó el primer punto)")

        Tape2 = turing1.read_input(cadenaJuego).pop().tapes[1].tape
        azul_puntos = 0
        for i in range(len(Tape2)):
                try:
                        azul_puntos = azul_puntos + int(Tape2[i])
                except ValueError:
                        continue

        Tape3 = turing1.read_input(cadenaJuego).pop().tapes[2].tape
        rojo_puntos = 0
        for i in range(len(Tape3)):
                try:
                        rojo_puntos = rojo_puntos + int(Tape3[i])
                except ValueError:
                        continue
        print("")
        print("MARCADOR FINAL: Ao ", azul_puntos, " - ", rojo_puntos, "Aka")

        Tape4 = turing1.read_input(cadenaJuego).pop().tapes[3].tape
        for i in range(len(Tape4)):
                play = Tape4[i]
                match play:
                        case "1":
                                print("Ao cometió 1 falta en total")
                        case "2":
                                print("Ao cometió 2 faltas en total")
                        case "3":
                                print("Ao cometió 3 faltas en total")
                        case "4":
                                print("Ao cometió 4 faltas en total")
                        case "5":
                                print("Ao cometió 5 faltas en total")
                        case "B" :
                                continue

        Tape5 = turing1.read_input(cadenaJuego).pop().tapes[4].tape
        for i in range(len(Tape5)):
                play = Tape5[i]
                match play:
                        case "1":
                                print("Aka cometió 1 falta en total")
                        case "2":
                                print("Aka cometió 2 faltas en total")
                        case "3":
                                print("Aka cometió 3 faltas en total")
                        case "4":
                                print("Aka cometió 4 faltas en total")
                        case "5":
                                print("Aka cometió 5 faltas en total")
                        case "B" :
                                continue

        results  = turing1.read_input(cadenaJuego)
        estado = results.pop()
        state = estado.state

        match state:
                case "qSR":
                        print("Aka: nokachi! (Rojo gana por senshu)")
                case "qSA":
                        print("Ao: nokachi! (Azul gana por senshu)")
                case "qFR":
                        print("Ao: hansoku! (Azul expulsado por acumulación de faltas)\nAka: nokachi! (Rojo gana)")
                case "qFA":
                        print("Aka: hansoku! (Rojo expulsado por acumulación de faltas)\nAo: nokachi! (Azul gana)")
                case "qA8":
                        print("Ao: nokachi! (Azul gana por puntaje)")
                case "qR8":
                        print("Aka: nokachi! (Rojo gana por puntaje)")
        print()
        print()


Combatir("R3YAR2R2RIR")
# Out:
# Cadena de combate: R3YAR2R2RIR
#
# Yame! Aka: chui! (Rojo cometió falta)
# Yame! Ao: ippon! (Azul marcó 3 puntos)
# Yame! Aka: yuko! (Rojo marcó 1 punto)
# Yame! Ao: chui! (Azul cometió falta)
# Yame! Aka: chui! (Rojo cometió falta)
# Yame! Ao: wazari! (Azul marcó 2 puntos)
# Yame! Aka: chui! (Rojo cometió falta)
# Yame! Ao: wazari! (Azul marcó 2 puntos)
# Yame! Aka: chui! (Rojo cometió falta)
# Yame! Aka: ippon! (Rojo marcó 3 puntos)
# Yame! Aka: chui! (Rojo cometió falta)
#
# MARCADOR FINAL: Ao  7  -  4 Aka
# Ao cometió 1 falta en total
# Aka cometió 5 faltas en total
# Aka: hansoku! (Rojo expulsado por acumulación de faltas)
# Ao: nokachi! (Azul gana)
